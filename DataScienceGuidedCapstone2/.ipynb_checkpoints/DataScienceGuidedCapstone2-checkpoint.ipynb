# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
City_Scores = pd.read_csv(r'C:\Users\Terry\Desktop\Data Sets\uaScoresDataFrame.csv')

# %%
City_Scores.head()
# Out:
#    Unnamed: 0      UA_Name    UA_Country   UA_Continent  Housing  \
# 0           0       Aarhus       Denmark         Europe   6.1315
# 1           1     Adelaide     Australia        Oceania   6.3095
# 2           2  Albuquerque    New Mexico  North America   7.2620
# 3           3       Almaty    Kazakhstan           Asia   9.2820
# 4           4    Amsterdam   Netherlands         Europe   3.0530
#
#    Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0           4.015    2.8270            2.512               3.5360  6.31175
# 1           4.692    3.1365            2.640               1.7765  5.33625
# 2           6.059    3.7720            1.493               1.4555  5.05575
# 3           9.333    2.4585            0.000               4.5920  5.87125
# 4           3.824    7.9715            6.107               8.3245  6.11850
#
#    ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# ...

# %%
NA_Cities = City_Scores[City_Scores['UA_Continent'] == 'North America']

# %%
NA_Cities.head()
# Out:
#     Unnamed: 0      UA_Name       UA_Country   UA_Continent  Housing  \
# 2            2  Albuquerque       New Mexico  North America   7.2620
# 5            5    Anchorage           Alaska  North America   5.4335
# 8            8    Asheville   North Carolina  North America   5.8560
# 11          11      Atlanta          Georgia  North America   4.9755
# 13          13       Austin            Texas  North America   4.3345
#
#     Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 2            6.059    3.7720            1.493               1.4555  5.05575
# 5            3.141    2.7945            0.000               1.7380  4.71525
# 8            5.311    3.5405            0.000               1.2095  1.35800
# 11           5.241    8.8350            7.257               5.2915  3.89775
# 13           5.355    9.2360            6.939               1.8515  4.33050
#
#     ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# ...

# %%
NA_Cities.columns
# Out:
# Index(['Unnamed: 0', 'UA_Name', 'UA_Country', 'UA_Continent', 'Housing',
#        'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity',
#        'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education',
#        'Environmental Quality', 'Economy', 'Taxation', 'Internet Access',
#        'Leisure & Culture', 'Tolerance', 'Outdoors'],
#       dtype='object')

# %%
NA_Cities.describe()
# Out:
#        Unnamed: 0    Housing  Cost of Living   Startups  Venture Capital  \
# count   87.000000  87.000000       87.000000  87.000000        87.000000
# mean   134.126437   5.514661        4.982345   5.319201         3.249103
# std     72.948182   2.164620        2.061353   2.318156         2.903137
# min      2.000000   0.000000        0.000000   0.000000         0.000000
# 25%     70.000000   4.270750        4.780500   3.784250         0.500000
# 50%    144.000000   6.128500        5.375000   4.736500         2.612000
# 75%    194.000000   6.960750        6.029500   6.777250         5.106000
# max    261.000000   9.527000        9.490000  10.000000        10.000000
#
#        Travel Connectivity    Commute  Business Freedom     Safety  \
# count            87.000000  87.000000         87.000000  87.000000
# mean              2.297701   3.707149          8.123916   5.392632
# std               1.256045   1.683966          1.502655   1.713242
# ...

# %%
NA_Cities_Clean = NA_Cities.drop(columns=['Unnamed: 0']).reset_index()

# %%
NA_Cities_Clean.head()
# Out:
#    index      UA_Name       UA_Country   UA_Continent  Housing  \
# 0      2  Albuquerque       New Mexico  North America   7.2620
# 1      5    Anchorage           Alaska  North America   5.4335
# 2      8    Asheville   North Carolina  North America   5.8560
# 3     11      Atlanta          Georgia  North America   4.9755
# 4     13       Austin            Texas  North America   4.3345
#
#    Cost of Living  Startups  Venture Capital  Travel Connectivity  Commute  \
# 0           6.059    3.7720            1.493               1.4555  5.05575
# 1           3.141    2.7945            0.000               1.7380  4.71525
# 2           5.311    3.5405            0.000               1.2095  1.35800
# 3           5.241    8.8350            7.257               5.2915  3.89775
# 4           5.355    9.2360            6.939               1.8515  4.33050
#
#    ...  Safety  Healthcare  Education  Environmental Quality  Economy  \
# ...

# %%
NA_Cities_Clean = NA_Cities_Clean.drop(columns=['index'])

# %%
NA_Cities_Clean.shape
# Out:
# (87, 20)

# %%
NA_Cities_Clean["UA_Country"]
# Out:
# 0                New Mexico
# 1                    Alaska
# 2            North Carolina
# 3                   Georgia
# 4                     Texas
#               ...
# 82                   Canada
# 83                   Canada
# 84                   Canada
# 85     District of Columbia
# 86                   Canada
# Name: UA_Country, Length: 87, dtype: object

# %%
NA_Cities_Clean.loc[NA_Cities_Clean['UA_Country'] == " North Carolina"]
# Out:
#       UA_Name       UA_Country   UA_Continent  Housing  Cost of Living  \
# 2   Asheville   North Carolina  North America   5.8560           5.311
# 15  Charlotte   North Carolina  North America   5.5490           4.987
# 66    Raleigh   North Carolina  North America   6.1285           5.610
#
#     Startups  Venture Capital  Travel Connectivity  Commute  Business Freedom  \
# 2     3.5405            0.000               1.2095  1.35800             8.671
# 15    6.2480            2.878               3.6790  4.13400             8.671
# 66    5.4970            5.157               1.7570  4.78425             8.671
#
#     Safety  Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 2   5.8525    6.725333     3.6245                8.49325   6.5145     4.062
# 15  5.3475    6.432333     3.6245                8.00925   6.5145     4.062
# 66  6.5225    6.677333     7.1165                8.58375   6.5145     4.062
#
# ...

# %%
NA_Cities_Clean.loc[NA_Cities_Clean['UA_Name'] == "Boston"]
# Out:
#   UA_Name      UA_Country   UA_Continent  Housing  Cost of Living  Startups  \
# 9  Boston   Massachusetts  North America      1.0           4.259     9.565
#
#    Venture Capital  Travel Connectivity  Commute  Business Freedom  Safety  \
# 9             10.0                3.215  4.39625             8.671   7.742
#
#    Healthcare  Education  Environmental Quality  Economy  Taxation  \
# 9       6.729     8.6245                 8.1705   6.5145     4.062
#
#    Internet Access  Leisure & Culture  Tolerance  Outdoors
# 9           5.7005              8.564     8.4815      5.66

# %%
NA_Cities_Clean.dtypes
# Out:
# UA_Name                   object
# UA_Country                object
# UA_Continent              object
# Housing                  float64
# Cost of Living           float64
# Startups                 float64
# Venture Capital          float64
# Travel Connectivity      float64
# Commute                  float64
# Business Freedom         float64
# Safety                   float64
# Healthcare               float64
# Education                float64
# Environmental Quality    float64
# Economy                  float64
# Taxation                 float64
# Internet Access          float64
# Leisure & Culture        float64
# Tolerance                float64
# Outdoors                 float64
# dtype: object

# %%
state_names = [' Alabama',' Alaska',' Arizona',' Arkansas',' California',' Colorado',' Connecticut',' Delaware',' Florida',' Georgia',' Hawaii',' Idaho',' Illinois',' Indiana',' Iowa',' Kansas',' Kentucky',' Louisiana',' Maine',' Maryland',' Massachusetts',' Michigan',' Minnesota',' Mississippi',' Missouri',' Montana',' Nebraska',' Nevada',' New Hampshire',' New Jersey',' New Mexico',' New York',' North Carolina',' North Dakota',' Ohio',' Oklahoma',' Oregon',' Pennsylvania',' Rhode Island',' South Carolina',' South Dakota',' Tennessee',' Texas',' Utah',' Vermont',' Virginia',' Washington',' West Virginia',' Wisconsin',' Wyoming']

# %%
data = {"UA_Country":state_names}

# %%
state_frame = pd.DataFrame(data)

# %%
state_frame
# Out:
#          UA_Country
# 0           Alabama
# 1            Alaska
# 2           Arizona
# 3          Arkansas
# 4        California
# 5          Colorado
# 6       Connecticut
# 7          Delaware
# 8           Florida
# 9           Georgia
# 10           Hawaii
# 11            Idaho
# 12         Illinois
# 13          Indiana
# 14             Iowa
# 15           Kansas
# 16         Kentucky
# 17        Louisiana
# 18            Maine
# 19         Maryland
# 20    Massachusetts
# 21         Michigan
# 22        Minnesota
# 23      Mississippi
# 24         Missouri
# 25          Montana
# 26         Nebraska
# 27           Nevada
# 28    New Hampshire
# 29       New Jersey
# 30       New Mexico
# 31         New York
# 32   North Carolina
# 33     North Dakota
# 34             Ohio
# 35         Oklahoma
# 36           Oregon
# 37     Pennsylvania
# 38     Rhode Island
# 39   South Carolina
# 40     South Dakota
# 41        Tennessee
# 42            Texas
# 43             Utah
# ...

# %%
 
newdf = pd.merge(NA_Cities_Clean, state_frame)
newdf.head(10)
# Out:
#        UA_Name       UA_Country   UA_Continent  Housing  Cost of Living  \
# 0  Albuquerque       New Mexico  North America   7.2620           6.059
# 1    Anchorage           Alaska  North America   5.4335           3.141
# 2    Asheville   North Carolina  North America   5.8560           5.311
# 3    Charlotte   North Carolina  North America   5.5490           4.987
# 4      Raleigh   North Carolina  North America   6.1285           5.610
# 5      Atlanta          Georgia  North America   4.9755           5.241
# 6       Austin            Texas  North America   4.3345           5.355
# 7       Dallas            Texas  North America   5.2590           6.091
# 8      Houston            Texas  North America   5.2245           6.162
# 9  San Antonio            Texas  North America   6.4020           6.683
#
#    Startups  Venture Capital  Travel Connectivity  Commute  Business Freedom  \
# 0    3.7720            1.493               1.4555  5.05575             8.671
# ...

# %%
newdf['UA_Continent'] = 'United States'

# %%
newdf = newdf.rename(columns = {'UA_Name':'City', 'UA_Country':'State', 'UA_Continent':'Country'})
newdf.head(10)
# Out:
#           City            State        Country  Housing  Cost of Living  \
# 0  Albuquerque       New Mexico  United States   7.2620           6.059
# 1    Anchorage           Alaska  United States   5.4335           3.141
# 2    Asheville   North Carolina  United States   5.8560           5.311
# 3    Charlotte   North Carolina  United States   5.5490           4.987
# 4      Raleigh   North Carolina  United States   6.1285           5.610
# 5      Atlanta          Georgia  United States   4.9755           5.241
# 6       Austin            Texas  United States   4.3345           5.355
# 7       Dallas            Texas  United States   5.2590           6.091
# 8      Houston            Texas  United States   5.2245           6.162
# 9  San Antonio            Texas  United States   6.4020           6.683
#
#    Startups  Venture Capital  Travel Connectivity  Commute  Business Freedom  \
# 0    3.7720            1.493               1.4555  5.05575             8.671
# ...

# %%
###This function takes a list as an argument and returns a data frame with only the rows matching each list value###
##def cities (list):
    ##for x in list:
        ##NA_Cities_Clean.drop(NA_Cities_Clean.loc[NA_Cities_Clean['UA_Country']!=x].index, inplace=True)
        ##df.drop(df.loc[df['line_race']==0].index, inplace=True)
    ##return NA_Cities_Clean

# %%
##cities(state_names)

# %%
##Importing Smart City additional data sets for merge

# %%
Smart_Cities = pd.read_csv(r'C:\Users\Terry\Desktop\Data Sets\Smart_City_index_headers.csv')

# %%
Smart_Cities.columns
# Out:
# Index(['Id', 'City', 'Country', 'Smart_Mobility ', 'Smart_Environment',
#        'Smart_Government ', 'Smart_Economy ', 'Smart_People', 'Smart_Living',
#        'SmartCity_Index', 'SmartCity_Index_relative_Edmonton'],
#       dtype='object')

# %%
Smart_Cities.head(10)
# Out:
#    Id        City        Country  Smart_Mobility   Smart_Environment  \
# 0   1        Oslo         Norway             6480               6512
# 1   2      Bergen         Norway             7097               6876
# 2   3   Amsterdam    Netherlands             7540               5558
# 3   4  Copenhagen        Denmark             7490               7920
# 4   5   Stockholm         Sweden             6122               7692
# 5   6    Montreal         Canada             7490               4848
# 6   7      Vienna        Austria             5683               7608
# 7   8      Odense        Denmark             6160               8404
# 8   9   Singapore      Singapore             5790               4344
# 9  10      Boston  United States             7870               5224
#
#    Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0               7516            4565          8618          9090
# 1               7350            4905          8050          9090
# ...

# %%
US_Smart_Cities = Smart_Cities[Smart_Cities['Country'] == 'United States']

# %%
US_Smart_Cities
# Out:
#     Id            City        Country  Smart_Mobility   Smart_Environment  \
# 9   10          Boston  United States             7870               5224
# 15  16  Washington, DC  United States             6848               5224
# 17  18     Los Angeles  United States             7745               4574
# 22  23        New York  United States             7607               4468
# 23  24         Chicago  United States             8110               4680
# 30  31    Philadelphia  United States             7478               4800
# 43  44   San Francisco  United States             7217               5148
#
#     Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 9                6020            8935          6573          6220
# 15               7474            8590          5930          6220
# 17               4750            7235          7498          6220
# 22               6038            6520          6610          6220
# ...

# %%
US_Smart_Cities_Indexed = US_Smart_Cities.reset_index()

# %%
US_Smart_Cities_Indexed
# Out:
#    index  Id            City        Country  Smart_Mobility   \
# 0      9  10          Boston  United States             7870
# 1     15  16  Washington, DC  United States             6848
# 2     17  18     Los Angeles  United States             7745
# 3     22  23        New York  United States             7607
# 4     23  24         Chicago  United States             8110
# 5     30  31    Philadelphia  United States             7478
# 6     43  44   San Francisco  United States             7217
#
#    Smart_Environment  Smart_Government   Smart_Economy   Smart_People  \
# 0               5224               6020            8935          6573
# 1               5224               7474            8590          5930
# 2               4574               4750            7235          7498
# 3               4468               6038            6520          6610
# 4               4680               5170            7265          7123
# ...

# %%
US_Smart_Cities_Indexed.rename(columns = {'index' : 'IMD Rank 2023'}).drop(columns=['Id'])
# Out:
#    IMD Rank 2023            City        Country  Smart_Mobility   \
# 0              9          Boston  United States             7870
# 1             15  Washington, DC  United States             6848
# 2             17     Los Angeles  United States             7745
# 3             22        New York  United States             7607
# 4             23         Chicago  United States             8110
# 5             30    Philadelphia  United States             7478
# 6             43   San Francisco  United States             7217
#
#    Smart_Environment  Smart_Government   Smart_Economy   Smart_People  \
# 0               5224               6020            8935          6573
# 1               5224               7474            8590          5930
# 2               4574               4750            7235          7498
# 3               4468               6038            6520          6610
# 4               4680               5170            7265          7123
# ...

# %%
df = pd.concat([newdf, US_Smart_Cities_Indexed], axis=0)
df
# Out:
#              City            State        Country  Housing  Cost of Living  \
# 0     Albuquerque       New Mexico  United States   7.2620           6.059
# 1       Anchorage           Alaska  United States   5.4335           3.141
# 2       Asheville   North Carolina  United States   5.8560           5.311
# 3       Charlotte   North Carolina  United States   5.5490           4.987
# 4         Raleigh   North Carolina  United States   6.1285           5.610
# ..            ...              ...            ...      ...             ...
# 2     Los Angeles              NaN  United States      NaN             NaN
# 3        New York              NaN  United States      NaN             NaN
# 4         Chicago              NaN  United States      NaN             NaN
# 5    Philadelphia              NaN  United States      NaN             NaN
# 6   San Francisco              NaN  United States      NaN             NaN
#
# ...

# %%
newdf = df.groupby(by='City').apply(lambda a: a[:])
newdf
# Out:
#               City            State        Country  Housing  Cost of Living  \
# 0      Albuquerque       New Mexico  United States   7.2620           6.059
# 0           Boston              NaN  United States      NaN             NaN
# 1        Anchorage           Alaska  United States   5.4335           3.141
# 1   Washington, DC              NaN  United States      NaN             NaN
# 2        Asheville   North Carolina  United States   5.8560           5.311
# ..             ...              ...            ...      ...             ...
# 59        Portland            Maine  United States   0.0000           0.000
# 60      Providence     Rhode Island  United States   3.1530           0.000
# 61        Richmond         Virginia  United States   6.4395           5.949
# 62  Salt Lake City             Utah  United States   6.1410           6.172
# 63         Seattle       Washington  United States   2.2910           3.790
#
# ...

# %%
newdf.loc[newdf['City'] == "Boston"]
# Out:
#       City           State        Country  Housing  Cost of Living  Startups  \
# 0   Boston             NaN  United States      NaN             NaN       NaN
# 13  Boston   Massachusetts  United States      1.0           4.259     9.565
#
#     Venture Capital  Travel Connectivity  Commute  Business Freedom  ...  \
# 0               NaN                  NaN      NaN               NaN  ...
# 13             10.0                3.215  4.39625             8.671  ...
#
#     index    Id  Smart_Mobility   Smart_Environment  Smart_Government   \
# 0     9.0  10.0           7870.0             5224.0             6020.0
# 13    NaN   NaN              NaN                NaN                NaN
#
#     Smart_Economy   Smart_People  Smart_Living  SmartCity_Index  \
# 0           8935.0        6573.0        6220.0           6852.0
# 13             NaN           NaN           NaN              NaN
#
#     SmartCity_Index_relative_Edmonton
# 0                               380.0
# ...
